# %%
#importing necessary package
from main import  clean_dataset
# %matplotlib inline

#specifications from user
main_directory = r"C:\IITB\Academics\DDP\AirPy"
year = 2020
mixed_unit_identification = False #to automate specify as False else, as True


#call the function inside main
clean_dataset(year, main_directory, mixed_unit_identification)
# Out:
# No NO data
# No NO2 data
# NO NOx data
# NO Ozone data
# ===========================================================================================
# Chandni Chowk, Delhi - IITM
# ===========================================================================================
# successfully cleaned  PM25   Chandni Chowk, Delhi - IITM
# successfully cleaned  PM10   Chandni Chowk, Delhi - IITM
# No available  NOx  data
# No available  NO2  data
# No available  NO  data
# No available  Ozone  data
# > c:\iitb\academics\ddp\airpy\main.py(91)clean_dataset()
# -> print(colored("----------------------------------------------------------------------------------------", 'red', attrs=['bold']))
# (Pdb) c
# ----------------------------------------------------------------------------------------
# error in unit identification forOzone Chandni Chowk, Delhi - IITM
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# saved successfully forChandni Chowk, Delhi - IITM
# ----------------------------------------------------------------------------------------
# No NO data
# No NO2 data
# NO NOx data
# NO Ozone data
# ===========================================================================================
# Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB
# ===========================================================================================
# successfully cleaned  PM25   Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB
# successfully cleaned  PM10   Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB
# No available  NOx  data
# No available  NO2  data
# No available  NO  data
# No available  Ozone  data
# > c:\iitb\academics\ddp\airpy\main.py(90)clean_dataset()
# -> import pdb; pdb.set_trace()
# (Pdb) c
# ----------------------------------------------------------------------------------------
# error in unit identification forOzone Chhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# saved successfully forChhatrapati Shivaji Intl. Airport (T2), Mumbai - MPCB
# ----------------------------------------------------------------------------------------
# No NO data
# No NO2 data
# NO NOx data
# NO Ozone data
# ===========================================================================================
# ITO, Delhi - CPCB
# ===========================================================================================
# successfully cleaned  PM25   ITO, Delhi - CPCB
# successfully cleaned  PM10   ITO, Delhi - CPCB
# No available  NOx  data
# No available  NO2  data
# No available  NO  data
# No available  Ozone  data
# > c:\iitb\academics\ddp\airpy\main.py(91)clean_dataset()
# -> print(colored("----------------------------------------------------------------------------------------", 'red', attrs=['bold']))
# (Pdb) c
# ----------------------------------------------------------------------------------------
# error in unit identification forOzone ITO, Delhi - CPCB
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# saved successfully forITO, Delhi - CPCB
# ----------------------------------------------------------------------------------------
# No NO data
# No NO2 data
# NO NOx data
# NO Ozone data
# ===========================================================================================
# Lodhi Road, Delhi - IMD
# ===========================================================================================
# successfully cleaned  PM25   Lodhi Road, Delhi - IMD
# successfully cleaned  PM10   Lodhi Road, Delhi - IMD
# No available  NOx  data
# No available  NO2  data
# No available  NO  data
# No available  Ozone  data
# > c:\iitb\academics\ddp\airpy\main.py(90)clean_dataset()
# -> import pdb; pdb.set_trace()
# (Pdb) c
# ----------------------------------------------------------------------------------------
# error in unit identification forOzone Lodhi Road, Delhi - IMD
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# saved successfully forLodhi Road, Delhi - IMD
# ----------------------------------------------------------------------------------------
# No NO data
# No NO2 data
# NO NOx data
# NO Ozone data
# ===========================================================================================
# Powai, Mumbai - MPCB
# ===========================================================================================
# successfully cleaned  PM25   Powai, Mumbai - MPCB
# successfully cleaned  PM10   Powai, Mumbai - MPCB
# No available  NOx  data
# No available  NO2  data
# No available  NO  data
# No available  Ozone  data
# > c:\iitb\academics\ddp\airpy\main.py(91)clean_dataset()
# -> print(colored("----------------------------------------------------------------------------------------", 'red', attrs=['bold']))
# (Pdb) c
# ----------------------------------------------------------------------------------------
# error in unit identification forOzone Powai, Mumbai - MPCB
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# saved successfully forPowai, Mumbai - MPCB
# ----------------------------------------------------------------------------------------
